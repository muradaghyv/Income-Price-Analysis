# %%
import pandas as pd

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from scipy.stats import rankdata, norm

from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor

# %%
df = pd.read_csv("data.csv")

# %%
y = df["Income"]

# %%
df["Work_Experience_rank"] = rankdata(df["Work_Experience"])
df["Work_Experience_rank_norm"] = norm.ppf((df["Work_Experience_rank"] - 0.5) / len(df["Work_Experience_rank"]))

# %%
X = df[["Work_Experience_rank_norm", 'Education_Level', 'Occupation', 'Location', 'Employment_Status',
        'Homeownership_Status', 'Type_of_Housing']]

# %%
X
# Out:
#       Work_Experience_rank_norm Education_Level  Occupation  Location  \
# 0                     -0.194863        Master's  Technology     Urban
# 1                     -1.331575     High School     Finance     Urban
# 2                     -1.886705      Bachelor's  Technology     Urban
# 3                      0.356989     High School      Others     Urban
# 4                     -0.515076      Bachelor's     Finance     Urban
# ...                         ...             ...         ...       ...
# 9995                   0.056052     High School      Others  Suburban
# 9996                  -0.459605        Master's  Technology     Urban
# 9997                   2.393247       Doctorate   Education     Urban
# 9998                  -1.461421     High School   Education     Urban
# 9999                   1.682355     High School  Healthcare  Suburban
#
#      Employment_Status Homeownership_Status     Type_of_Housing
# 0            Full-time                  Own           Apartment
# 1            Full-time                  Own           Apartment
# 2            Full-time                  Own  Single-family home
# 3            Full-time                  Own           Apartment
# 4        Self-employed                  Own           Townhouse
# ...                ...                  ...                 ...
# 9995         Full-time                  Own           Townhouse
# 9996         Full-time                  Own  Single-family home
# 9997         Full-time                  Own  Single-family home
# 9998         Part-time                  Own  Single-family home
# 9999         Part-time                 Rent  Single-family home
#
# [10000 rows x 7 columns]

# %%
X = pd.get_dummies(X, columns=["Occupation", "Location", "Employment_Status", "Homeownership_Status", "Type_of_Housing"],
                  dtype="int8")
X["Education_Level"] = X["Education_Level"].replace({"High School":0,
                                                        "Bachelor's":1,
                                                        "Master's":2,
                                                        "Doctorate":3})
# Out:
# /tmp/ipykernel_16473/391221571.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X["Education_Level"] = X["Education_Level"].replace({"High School":0,

# %%
test_data_x = X.iloc[9951:]
test_data_y = y.iloc[9951:]

# %%
X = X[:9950]
y = y[:9950]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.75)

# %%
dtr = DecisionTreeRegressor()
dtr.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
prediction = dtr.predict(X_test)

# %%
scores = cross_val_score(dtr, X_train, y_train, cv=5, scoring='r2')
result = -scores.mean()
print(result)
# Out:
# 0.8192456116425207

# %%
mean_absolute_error(y_test, prediction)
# Out:
# 1054372.7720927116

# %%
r2_score(y_test, prediction)
# Out:
# -0.5235139702319065

# %%
# from sklearn.model_selection import train_test_split, cross_val_score
# from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
# from sklearn.tree import DecisionTreeRegressor
# from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
# from sklearn.svm import SVR
# from sklearn.neighbors import KNeighborsRegressor
# from xgboost import XGBRegressor
# from lightgbm import LGBMRegressor
# from catboost import CatBoostRegressor

# # List of models to try
# models = {
#     "Linear Regression": LinearRegression(),
#     "Ridge Regression": Ridge(),
#     "Lasso Regression": Lasso(),
#     "ElasticNet Regression": ElasticNet(),
#     "Decision Tree": DecisionTreeRegressor(),
#     "Random Forest": RandomForestRegressor(),
#     "Gradient Boosting": GradientBoostingRegressor(),
#     "XGBoost": XGBRegressor(),
#     "LightGBM": LGBMRegressor(),
#     "CatBoost": CatBoostRegressor(verbose=0),
#     "SVR": SVR(),
#     "KNN": KNeighborsRegressor()
# }

# # Train and evaluate each model
# results = {}
# for name, model in models.items():
#     scores = cross_val_score(model, X_train, y_train, cv=5, scoring='r2')
#     results[name] = -scores.mean()

# # Print results
# for name, score in results.items():
#     print(f"{name}: MAE = {scores}")

# %%
datapoint = [list(test_data_x.iloc[3].values)]

# %%
dtr.predict(datapoint)
# Out:
# /home/murad/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([1552014.])

# %%
test_data_y.iloc[3]
# Out:
# 2735664
